# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print (city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.

        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except Exception as E: 
        #raise E
        print("City not found. Skipping...")
        #pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sambava
# Processing Record 1 of Set 1 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hobart
# Processing Record 2 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=chara
# Processing Record 3 of Set 1 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=gamba
# Processing Record 4 of Set 1 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=iqaluit
# Processing Record 5 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=preeceville
# Processing Record 6 of Set 1 | preeceville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=obo
# Processing Record 7 of Set 1 | obo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nueva+loja
# Processing Record 8 of Set 1 | nueva loja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=leh
# Processing Record 9 of Set 1 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rafaela
# Processing Record 10 of Set 1 | rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tumbes
# Processing Record 11 of Set 1 | tumbes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rikitea
# Processing Record 12 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cape+town
# Processing Record 13 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ushuaia
# Processing Record 14 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kodiak
# Processing Record 15 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bontang
# Processing Record 16 of Set 1 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hilo
# Processing Record 17 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=manggar
# Processing Record 18 of Set 1 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=busselton
# Processing Record 19 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bambous+virieux
# Processing Record 20 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=taolanaro
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=touros
# Processing Record 22 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=trairi
# Processing Record 23 of Set 1 | trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=esperance
# Processing Record 24 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ventersburg
# Processing Record 25 of Set 1 | ventersburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=georgetown
# Processing Record 26 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lakatoro
# Processing Record 27 of Set 1 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=barrow
# Processing Record 28 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ribeira+grande
# Processing Record 29 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=okhotsk
# Processing Record 30 of Set 1 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kapaa
# Processing Record 31 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port+alfred
# Processing Record 32 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=talnakh
# Processing Record 33 of Set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cherskiy
# Processing Record 34 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=yellowknife
# Processing Record 35 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=provideniya
# Processing Record 36 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kizukuri
# Processing Record 37 of Set 1 | kizukuri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=skjervoy
# Processing Record 38 of Set 1 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mahebourg
# Processing Record 39 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=gornopravdinsk
# Processing Record 40 of Set 1 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tazovskiy
# Processing Record 41 of Set 1 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=naifaru
# Processing Record 42 of Set 1 | naifaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=wendo
# Processing Record 43 of Set 1 | wendo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=fairbanks
# Processing Record 44 of Set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port+elizabeth
# Processing Record 45 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mount+isa
# Processing Record 46 of Set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=udayagiri
# Processing Record 47 of Set 1 | udayagiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vaini
# Processing Record 48 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=khatanga
# Processing Record 49 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=severo-kurilsk
# Processing Record 50 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=punta+arenas
# Processing Record 1 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=klaksvik
# Processing Record 2 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=saint-philippe
# Processing Record 3 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bluff
# Processing Record 4 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=saint+anthony
# Processing Record 5 of Set 2 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=petropavlovsk-kamchatskiy
# Processing Record 6 of Set 2 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=belyy+yar
# Processing Record 7 of Set 2 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=santa+rita
# Processing Record 8 of Set 2 | santa rita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mount+gambier
# Processing Record 9 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=longyearbyen
# Processing Record 10 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kaitangata
# Processing Record 11 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=jamestown
# Processing Record 12 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=palabuhanratu
# Processing Record 13 of Set 2 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=souillac
# Processing Record 14 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=atuona
# Processing Record 15 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hambantota
# Processing Record 16 of Set 2 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tirumullaivasal
# Processing Record 17 of Set 2 | tirumullaivasal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tsiroanomandidy
# Processing Record 18 of Set 2 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=thompson
# Processing Record 19 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=leningradskiy
# Processing Record 20 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mataura
# Processing Record 21 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port+hardy
# Processing Record 22 of Set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=upernavik
# Processing Record 23 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=warqla
# Processing Record 24 of Set 2 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pitea
# Processing Record 25 of Set 2 | pitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=alotau
# Processing Record 26 of Set 2 | alotau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=fortuna
# Processing Record 27 of Set 2 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=katsuura
# Processing Record 28 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=myaundzha
# Processing Record 29 of Set 2 | myaundzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nikolskoye
# Processing Record 30 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vila+franca+do+campo
# Processing Record 31 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ulaanbaatar
# Processing Record 32 of Set 2 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=amurzet
# Processing Record 33 of Set 2 | amurzet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=boa+vista
# Processing Record 34 of Set 2 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ilulissat
# Processing Record 35 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hermanus
# Processing Record 36 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=amderma
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=dikson
# Processing Record 38 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bengkulu
# Processing Record 39 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lebu
# Processing Record 40 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nizhneyansk
# Processing Record 41 of Set 2 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=marivan
# Processing Record 42 of Set 2 | marivan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=chiang+klang
# Processing Record 43 of Set 2 | chiang klang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kruisfontein
# Processing Record 44 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hasaki
# Processing Record 45 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=albany
# Processing Record 46 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=taunggyi
# Processing Record 47 of Set 2 | taunggyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=satitoa
# Processing Record 48 of Set 2 | satitoa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=avarua
# Processing Record 49 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ijaki
# Processing Record 50 of Set 2 | ijaki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=belushya+guba
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=barentsburg
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=colquechaca
# Processing Record 3 of Set 3 | colquechaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=dingle
# Processing Record 4 of Set 3 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sangar
# Processing Record 5 of Set 3 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bend
# Processing Record 6 of Set 3 | bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=constitucion
# Processing Record 7 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=uddevalla
# Processing Record 8 of Set 3 | uddevalla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=chiredzi
# Processing Record 9 of Set 3 | chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mys+shmidta
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=namatanai
# Processing Record 11 of Set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=butaritari
# Processing Record 12 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sur
# Processing Record 13 of Set 3 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=amapa
# Processing Record 14 of Set 3 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nome
# Processing Record 15 of Set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sao+filipe
# Processing Record 16 of Set 3 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=acapulco
# Processing Record 17 of Set 3 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bethel
# Processing Record 18 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=xiongzhou
# Processing Record 19 of Set 3 | xiongzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sioux+lookout
# Processing Record 20 of Set 3 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=palana
# Processing Record 21 of Set 3 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=taltal
# Processing Record 22 of Set 3 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sumbawa
# Processing Record 23 of Set 3 | sumbawa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lata
# Processing Record 24 of Set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=aguimes
# Processing Record 25 of Set 3 | aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=carnarvon
# Processing Record 26 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hofn
# Processing Record 27 of Set 3 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=saskylakh
# Processing Record 28 of Set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lorengau
# Processing Record 29 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mahibadhoo
# Processing Record 30 of Set 3 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cehegin
# Processing Record 31 of Set 3 | cehegin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=khonuu
# Processing Record 32 of Set 3 | khonuu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=saldanha
# Processing Record 33 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=christchurch
# Processing Record 34 of Set 3 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pangnirtung
# Processing Record 35 of Set 3 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=clemson
# Processing Record 36 of Set 3 | clemson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tsihombe
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ahipara
# Processing Record 38 of Set 3 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ahuimanu
# Processing Record 39 of Set 3 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mahajanga
# Processing Record 40 of Set 3 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=oparino
# Processing Record 41 of Set 3 | oparino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=takoradi
# Processing Record 42 of Set 3 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=paamiut
# Processing Record 43 of Set 3 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=launceston
# Processing Record 44 of Set 3 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=alto+araguaia
# Processing Record 45 of Set 3 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=opportunity
# Processing Record 46 of Set 3 | opportunity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tuatapere
# Processing Record 47 of Set 3 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=madison
# Processing Record 48 of Set 3 | madison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=broome
# Processing Record 49 of Set 3 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nagornyy
# Processing Record 50 of Set 3 | nagornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sitka
# Processing Record 1 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=castro
# Processing Record 2 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=deputatskiy
# Processing Record 3 of Set 4 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nyurba
# Processing Record 4 of Set 4 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=illoqqortoormiut
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=arawa
# Processing Record 6 of Set 4 | arawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=flinders
# Processing Record 7 of Set 4 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=olinda
# Processing Record 8 of Set 4 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=maykor
# Processing Record 9 of Set 4 | maykor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tuktoyaktuk
# Processing Record 10 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tateyama
# Processing Record 11 of Set 4 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port+lincoln
# Processing Record 12 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=richards+bay
# Processing Record 13 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kemijarvi
# Processing Record 14 of Set 4 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cidreira
# Processing Record 15 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lerwick
# Processing Record 16 of Set 4 | lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kankon
# Processing Record 17 of Set 4 | kankon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=margate
# Processing Record 18 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=homer
# Processing Record 19 of Set 4 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pisco
# Processing Record 20 of Set 4 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bredasdorp
# Processing Record 21 of Set 4 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=new+norfolk
# Processing Record 22 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=yarovoye
# Processing Record 23 of Set 4 | yarovoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=salinopolis
# Processing Record 24 of Set 4 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mnogovershinnyy
# Processing Record 25 of Set 4 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ghugus
# Processing Record 26 of Set 4 | ghugus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tasiilaq
# Processing Record 27 of Set 4 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=likasi
# Processing Record 28 of Set 4 | likasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port-cartier
# Processing Record 29 of Set 4 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kavaratti
# Processing Record 30 of Set 4 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=norman+wells
# Processing Record 31 of Set 4 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=skibotn
# Processing Record 32 of Set 4 | skibotn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pevek
# Processing Record 33 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=dryden
# Processing Record 34 of Set 4 | dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=chuy
# Processing Record 35 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kichera
# Processing Record 36 of Set 4 | kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=anju
# Processing Record 37 of Set 4 | anju
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=aquidauana
# Processing Record 38 of Set 4 | aquidauana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=clyde+river
# Processing Record 39 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kaeo
# Processing Record 40 of Set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=te+anau
# Processing Record 41 of Set 4 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cabo+san+lucas
# Processing Record 42 of Set 4 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=imbituba
# Processing Record 43 of Set 4 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=arraial+do+cabo
# Processing Record 44 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=geraldton
# Processing Record 45 of Set 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mawlaik
# Processing Record 46 of Set 4 | mawlaik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=grand+river+south+east
# Processing Record 47 of Set 4 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ponta+do+sol
# Processing Record 48 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=malkangiri
# Processing Record 49 of Set 4 | malkangiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tromso
# Processing Record 50 of Set 4 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=cap+malheureux
# Processing Record 1 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=north+atlanta
# Processing Record 2 of Set 5 | north atlanta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=qaanaaq
# Processing Record 3 of Set 5 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tautira
# Processing Record 4 of Set 5 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ayan
# Processing Record 5 of Set 5 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=victoria
# Processing Record 6 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=alofi
# Processing Record 7 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=soyo
# Processing Record 8 of Set 5 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=puerto+ayora
# Processing Record 9 of Set 5 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=aripuana
# Processing Record 10 of Set 5 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=teknaf
# Processing Record 11 of Set 5 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=thio
# Processing Record 12 of Set 5 | thio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nouadhibou
# Processing Record 13 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=shakawe
# Processing Record 14 of Set 5 | shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ponta+delgada
# Processing Record 15 of Set 5 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=isangel
# Processing Record 16 of Set 5 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rawannawi
# Processing Record 17 of Set 5 | rawannawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=meulaboh
# Processing Record 18 of Set 5 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=saleaula
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=faridpur
# Processing Record 20 of Set 5 | faridpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=chillicothe
# Processing Record 21 of Set 5 | chillicothe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tecate
# Processing Record 22 of Set 5 | tecate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nhulunbuy
# Processing Record 23 of Set 5 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=waingapu
# Processing Record 24 of Set 5 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port+macquarie
# Processing Record 25 of Set 5 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=wittlich
# Processing Record 26 of Set 5 | wittlich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kupino
# Processing Record 27 of Set 5 | kupino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=owosso
# Processing Record 28 of Set 5 | owosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kenai
# Processing Record 29 of Set 5 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mattoon
# Processing Record 30 of Set 5 | mattoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vaitupu
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=coahuayana
# Processing Record 32 of Set 5 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=seydi
# Processing Record 33 of Set 5 | seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=suez
# Processing Record 34 of Set 5 | suez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sinnamary
# Processing Record 35 of Set 5 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=northam
# Processing Record 36 of Set 5 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=burgos
# Processing Record 37 of Set 5 | burgos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=shkotovo-22
# Processing Record 38 of Set 5 | shkotovo-22
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ancud
# Processing Record 39 of Set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=airai
# Processing Record 40 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=attawapiskat
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=faanui
# Processing Record 42 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=joaquim+nabuco
# Processing Record 43 of Set 5 | joaquim nabuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=maldonado
# Processing Record 44 of Set 5 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=leo
# Processing Record 45 of Set 5 | leo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=husavik
# Processing Record 46 of Set 5 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pak+phanang
# Processing Record 47 of Set 5 | pak phanang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=abomsa
# Processing Record 48 of Set 5 | abomsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vanderhoof
# Processing Record 49 of Set 5 | vanderhoof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nelson+bay
# Processing Record 50 of Set 5 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=taga
# Processing Record 1 of Set 6 | taga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=asau
# Processing Record 2 of Set 6 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nemuro
# Processing Record 3 of Set 6 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sobolevo
# Processing Record 4 of Set 6 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=moussoro
# Processing Record 5 of Set 6 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=port-gentil
# Processing Record 6 of Set 6 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tolaga+bay
# Processing Record 7 of Set 6 | tolaga bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=samusu
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mar+del+plata
# Processing Record 9 of Set 6 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bargal
# Processing Record 10 of Set 6 | bargal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tumannyy
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=manturovo
# Processing Record 12 of Set 6 | manturovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=plettenberg+bay
# Processing Record 13 of Set 6 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=luga
# Processing Record 14 of Set 6 | luga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=praia+da+vitoria
# Processing Record 15 of Set 6 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mandalgovi
# Processing Record 16 of Set 6 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=weligama
# Processing Record 17 of Set 6 | weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bandarbeyla
# Processing Record 18 of Set 6 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=santiago+de+chuco
# Processing Record 19 of Set 6 | santiago de chuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=gizo
# Processing Record 20 of Set 6 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hithadhoo
# Processing Record 21 of Set 6 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=krasnyy+yar
# Processing Record 22 of Set 6 | krasnyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ginda
# Processing Record 23 of Set 6 | ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vila+velha
# Processing Record 24 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=alice+springs
# Processing Record 25 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=contamana
# Processing Record 26 of Set 6 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mbigou
# Processing Record 27 of Set 6 | mbigou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ulkan
# Processing Record 28 of Set 6 | ulkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=umzimvubu
# Processing Record 29 of Set 6 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=guerrero+negro
# Processing Record 30 of Set 6 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pemba
# Processing Record 31 of Set 6 | pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=atar
# Processing Record 32 of Set 6 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=xuddur
# Processing Record 33 of Set 6 | xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kokopo
# Processing Record 34 of Set 6 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=makasar
# Processing Record 35 of Set 6 | makasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sistranda
# Processing Record 36 of Set 6 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=coihaique
# Processing Record 37 of Set 6 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=codrington
# Processing Record 38 of Set 6 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=yongzhou
# Processing Record 39 of Set 6 | yongzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=williamsport
# Processing Record 40 of Set 6 | williamsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=torbay
# Processing Record 41 of Set 6 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=juba
# Processing Record 42 of Set 6 | juba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=churapcha
# Processing Record 43 of Set 6 | churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vila+do+maio
# Processing Record 44 of Set 6 | vila do maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kazalinsk
# Processing Record 45 of Set 6 | kazalinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=padang
# Processing Record 46 of Set 6 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=la+ronge
# Processing Record 47 of Set 6 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nabire
# Processing Record 48 of Set 6 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nambucca+heads
# Processing Record 49 of Set 6 | nambucca heads
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=porvoo
# Processing Record 50 of Set 6 | porvoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kavieng
# Processing Record 1 of Set 7 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=zyryanka
# Processing Record 2 of Set 7 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hope
# Processing Record 3 of Set 7 | hope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=karratha
# Processing Record 4 of Set 7 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bagdarin
# Processing Record 5 of Set 7 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=palauig
# Processing Record 6 of Set 7 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ferkessedougou
# Processing Record 7 of Set 7 | ferkessedougou
# ...
# Processing Record 15 of Set 14 | sarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=college
# Processing Record 16 of Set 14 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rubiataba
# Processing Record 17 of Set 14 | rubiataba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=that+phanom
# Processing Record 18 of Set 14 | that phanom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hirara
# Processing Record 19 of Set 14 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sloboda
# Processing Record 20 of Set 14 | sloboda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kathu
# Processing Record 21 of Set 14 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=gra+liyia
# Processing Record 22 of Set 14 | gra liyia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=antofagasta
# Processing Record 23 of Set 14 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=birnin+kebbi
# Processing Record 24 of Set 14 | birnin kebbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sri+aman
# Processing Record 25 of Set 14 | sri aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=straldza
# Processing Record 26 of Set 14 | straldza
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=acajutla
# Processing Record 27 of Set 14 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=palembang
# Processing Record 28 of Set 14 | palembang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=corvallis
# Processing Record 29 of Set 14 | corvallis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sao+jose+da+coroa+grande
# Processing Record 30 of Set 14 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=las+palmas
# Processing Record 31 of Set 14 | las palmas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=nishihara
# Processing Record 32 of Set 14 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=messina
# Processing Record 33 of Set 14 | messina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=grand+gaube
# Processing Record 34 of Set 14 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=miranda
# Processing Record 35 of Set 14 | miranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mahon
# Processing Record 36 of Set 14 | mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=wanderlandia
# Processing Record 37 of Set 14 | wanderlandia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=polunochnoye
# Processing Record 38 of Set 14 | polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=itaituba
# Processing Record 39 of Set 14 | itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ostrovnoy
# Processing Record 40 of Set 14 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=toora-khem
# Processing Record 41 of Set 14 | toora-khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vallenar
# Processing Record 42 of Set 14 | vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=maceio
# Processing Record 43 of Set 14 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=arlit
# Processing Record 44 of Set 14 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=esperanza
# Processing Record 45 of Set 14 | esperanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=verkhoyansk
# Processing Record 46 of Set 14 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=faya
# Processing Record 47 of Set 14 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=north+bend
# Processing Record 48 of Set 14 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=shablykino
# Processing Record 49 of Set 14 | shablykino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pijijiapan
# Processing Record 50 of Set 14 | pijijiapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=aloleng
# Processing Record 1 of Set 15 | aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mitsamiouli
# Processing Record 2 of Set 15 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=russell
# Processing Record 3 of Set 15 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=umm+lajj
# Processing Record 4 of Set 15 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=san+antonio
# Processing Record 5 of Set 15 | san antonio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tingrela
# Processing Record 6 of Set 15 | tingrela
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=akhtanizovskaya
# Processing Record 7 of Set 15 | akhtanizovskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sorland
# Processing Record 8 of Set 15 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=san+francisco
# Processing Record 9 of Set 15 | san francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=laguna
# Processing Record 10 of Set 15 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tadotsu
# Processing Record 11 of Set 15 | tadotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tessalit
# Processing Record 12 of Set 15 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=inverness
# Processing Record 13 of Set 15 | inverness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tres+palos
# Processing Record 14 of Set 15 | tres palos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tomatlan
# Processing Record 15 of Set 15 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=hapao
# Processing Record 16 of Set 15 | hapao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pemangkat
# Processing Record 17 of Set 15 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=jati
# Processing Record 18 of Set 15 | jati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tambura
# Processing Record 19 of Set 15 | tambura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mjolby
# Processing Record 20 of Set 15 | mjolby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=morro+bay
# Processing Record 21 of Set 15 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=san+luis
# Processing Record 22 of Set 15 | san luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=broken+hill
# Processing Record 23 of Set 15 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=mentok
# Processing Record 24 of Set 15 | mentok
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=plesna
# Processing Record 25 of Set 15 | plesna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rocha
# Processing Record 26 of Set 15 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lujiang
# Processing Record 27 of Set 15 | lujiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tommot
# Processing Record 28 of Set 15 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sao+paulo+do+potengi
# Processing Record 29 of Set 15 | sao paulo do potengi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lufilufi
# Processing Record 30 of Set 15 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=batsfjord
# Processing Record 31 of Set 15 | batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tonstad
# Processing Record 32 of Set 15 | tonstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=galle
# Processing Record 33 of Set 15 | galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=manzanillo
# Processing Record 34 of Set 15 | manzanillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ahvaz
# Processing Record 35 of Set 15 | ahvaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=harderwijk
# Processing Record 36 of Set 15 | harderwijk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=emet
# Processing Record 37 of Set 15 | emet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=fort+abbas
# Processing Record 38 of Set 15 | fort abbas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tiarei
# Processing Record 39 of Set 15 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=keflavik
# Processing Record 40 of Set 15 | keflavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=sarkand
# Processing Record 41 of Set 15 | sarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=tuy+hoa
# Processing Record 42 of Set 15 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=monroe
# Processing Record 43 of Set 15 | monroe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bethanien
# Processing Record 44 of Set 15 | bethanien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=leshukonskoye
# Processing Record 45 of Set 15 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=lasa
# Processing Record 46 of Set 15 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ekhabi
# Processing Record 47 of Set 15 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=bambanglipuro
# Processing Record 48 of Set 15 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pravda
# Processing Record 49 of Set 15 | pravda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=yarmouth
# Processing Record 50 of Set 15 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=vostok
# Processing Record 1 of Set 16 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=ningan
# Processing Record 2 of Set 16 | ningan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=skovorodino
# Processing Record 3 of Set 16 | skovorodino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=one+hundred+mile+house
# Processing Record 4 of Set 16 | one hundred mile house
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=rundu
# Processing Record 5 of Set 16 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=haimen
# Processing Record 6 of Set 16 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=falealupo
# Processing Record 7 of Set 16 | falealupo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=abiramam
# Processing Record 8 of Set 16 | abiramam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=shimanovsk
# Processing Record 9 of Set 16 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=turukhansk
# Processing Record 10 of Set 16 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=toul
# Processing Record 11 of Set 16 | toul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=pauini
# Processing Record 12 of Set 16 | pauini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=challans
# Processing Record 13 of Set 16 | challans
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=maragogi
# Processing Record 14 of Set 16 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=olenino
# Processing Record 15 of Set 16 | olenino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be7298bd5516a0f252c4b9ad263e863f&q=kupang
# Processing Record 16 of Set 16 | kupang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Sambava      MG -14.2667   50.1667     77.29        85          32
# 1       Hobart      AU -42.8794  147.3294     57.06        71          92
# 2        Chara      RU  56.9064  118.2631    -19.50        96         100
# 3        Gamba      GA  -2.6500   10.0000     82.04        75          50
# 4      Iqaluit      CA  63.7506  -68.5145    -24.07        62          20
# 5  Preeceville      CA  51.9500 -102.6677     -6.45        96          92
# 6          Obo      CF   5.3998   26.4869     92.88        18          87
# 7   Nueva Loja      EC   0.0847  -76.8828     80.08        78           0
# 8          Leh      IN  34.1667   77.5833      2.07        64         100
# 9      Rafaela      AR -31.2503  -61.4867     71.01        54          82
#
#    Wind Speed Current Description
# 0        7.90       moderate rain
# 1        9.22     overcast clouds
# 2        0.78     overcast clouds
# 3       10.60    scattered clouds
# 4        2.30          few clouds
# 5        7.52     overcast clouds
# 6        6.06     overcast clouds
# 7        2.30       moderate rain
# 8        2.04     overcast clouds
# 9       14.52       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
